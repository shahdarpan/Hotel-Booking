# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Dell_Owner/Desktop/Project_650/hotel_bookings.csv')
df.head().T
# Out:
#                                            0             1             2  \
# hotel                           Resort Hotel  Resort Hotel  Resort Hotel
# is_canceled                                0             0             0
# lead_time                                342           737             7
# arrival_date_year                       2015          2015          2015
# arrival_date_month                      July          July          July
# arrival_date_week_number                  27            27            27
# arrival_date_day_of_month                  1             1             1
# stays_in_weekend_nights                    0             0             0
# stays_in_week_nights                       0             0             1
# adults                                     2             2             1
# children                                   0             0             0
# babies                                     0             0             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
df['Family'] = 0
df['Family'][(df['children'] > 0)] = 1
df['Family'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    110800
# 1      8590
# Name: Family, dtype: int64

# %%
df['distribution_channel_new'] = 0
df['distribution_channel_new'][df['distribution_channel'] == 'TA/TO'] = 1
df['distribution_channel_new'][df['distribution_channel'] == 'Corporate'] = 2
df['distribution_channel_new'][df['distribution_channel'] == 'Direct'] = 3
df['distribution_channel_new'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['stays_in_weekend_nights'][df['stays_in_weekend_nights'] >= 1] =1
df['stays_in_weekend_nights'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1    67392
# 0    51998
# Name: stays_in_weekend_nights, dtype: int64

# %%
df['stays_in_week_nights'][df['stays_in_week_nights'] >= 1] =1
df['stays_in_week_nights'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1    111745
# 0      7645
# Name: stays_in_week_nights, dtype: int64

# %%
df['adr_bin'] = 0
df['adr_bin'][(df['adr'] <=50)] = 1
df['adr_bin'][(df['adr'] > 50) & (df['adr']<=100)] = 2
df['adr_bin'][(df['adr'] > 100) & (df['adr']<=150)] = 3
df['adr_bin'][(df['adr'] > 150)] = 4
df['adr_bin'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['lead_time'].hist()

# %%
df['lead_time_bin'] = 0
df['lead_time_bin'][(df['lead_time'] <=30)] = 1
df['lead_time_bin'][(df['lead_time'] > 30) & (df['lead_time']<=60)] = 2
df['lead_time_bin'][(df['lead_time'] > 60) & (df['lead_time']<=90)] = 3
df['lead_time_bin'][(df['lead_time'] > 90)] = 4
df['lead_time_bin'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.head().T
# Out:
#                                            0             1             2  \
# hotel                           Resort Hotel  Resort Hotel  Resort Hotel
# is_canceled                                0             0             0
# lead_time                                342           737             7
# arrival_date_year                       2015          2015          2015
# arrival_date_month                      July          July          July
# arrival_date_week_number                  27            27            27
# arrival_date_day_of_month                  1             1             1
# stays_in_weekend_nights                    0             0             0
# stays_in_week_nights                       0             0             1
# adults                                     2             2             1
# children                                   0             0             0
# babies                                     0             0             0
# ...

# %%
df['is_repeated_guest'].value_counts()
# Out:
# 0    115580
# 1      3810
# Name: is_repeated_guest, dtype: int64

# %%
df['previous_bookings_not_canceled'][df['previous_bookings_not_canceled'] >= 1] =1
df['previous_bookings_not_canceled'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0    115770
# 1      3620
# Name: previous_bookings_not_canceled, dtype: int64

# %%
df['previous_cancellations'][df['previous_cancellations'] >= 1] =1
df['previous_cancellations'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0    112906
# 1      6484
# Name: previous_cancellations, dtype: int64

# %%
df['reserved_room_type'].value_counts()
# Out:
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: reserved_room_type, dtype: int64

# %%
df['assigned_room_type'].value_counts()
# Out:
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: assigned_room_type, dtype: int64

# %%
df['wrong_room'] = 1
df['wrong_room'][df['reserved_room_type'] == df['assigned_room_type']] = 0
df['wrong_room'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    104473
# 1     14917
# Name: wrong_room, dtype: int64

# %%
df['waiting_list'] = 0
df['waiting_list'][df['days_in_waiting_list'] != 0] = 1
df['waiting_list'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0    115692
# 1      3698
# Name: waiting_list, dtype: int64

# %%
df['customer_type_new'] = 0
df['customer_type_new'][df['customer_type'] == 'Transient'] = 1
df['customer_type_new'][df['customer_type'] == 'Contract'] = 2
df['customer_type_new'][df['customer_type'] == 'Transient-Party'] = 3
df['customer_type_new'][df['customer_type'] == 'Group'] = 4
df['customer_type_new'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.head().T
# Out:
#                                            0             1             2  \
# hotel                           Resort Hotel  Resort Hotel  Resort Hotel
# is_canceled                                0             0             0
# lead_time                                342           737             7
# arrival_date_year                       2015          2015          2015
# arrival_date_month                      July          July          July
# arrival_date_week_number                  27            27            27
# arrival_date_day_of_month                  1             1             1
# stays_in_weekend_nights                    0             0             0
# stays_in_week_nights                       0             0             1
# adults                                     2             2             1
# children                                   0             0             0
# babies                                     0             0             0
# ...

# %%
df['no_deposit'] = 0
df['no_deposit'][df['deposit_type'] == 'No Deposit'] = 1
df['no_deposit'].value_counts()
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    104641
# 0     14749
# Name: no_deposit, dtype: int64

# %%
sample = df[['is_canceled','lead_time_bin','is_repeated_guest','previous_cancellations','wrong_room','customer_type_new','no_deposit','Family','distribution_channel_new','adr_bin','stays_in_weekend_nights']]

# %%
sample.head().T
# Out:
#                           0  1  2  3  4
# is_canceled               0  0  0  0  0
# lead_time_bin             4  4  1  1  1
# is_repeated_guest         0  0  0  0  0
# previous_cancellations    0  0  0  0  0
# wrong_room                0  0  1  0  0
# customer_type_new         1  1  1  1  1
# no_deposit                1  1  1  1  1
# Family                    0  0  0  0  0
# distribution_channel_new  3  3  3  2  1
# adr_bin                   1  1  2  2  2
# stays_in_weekend_nights   0  0  0  0  0

# %%
sample.isna().sum()
# Out:
# is_canceled                 0
# lead_time_bin               0
# is_repeated_guest           0
# previous_cancellations      0
# wrong_room                  0
# customer_type_new           0
# no_deposit                  0
# Family                      0
# distribution_channel_new    0
# adr_bin                     0
# stays_in_weekend_nights     0
# dtype: int64

# %%
sample['lead_time_bin'].dtype
# Out:
# dtype('int64')

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   is_canceled               119390 non-null  int64
#  1   lead_time_bin             119390 non-null  int64
#  2   is_repeated_guest         119390 non-null  int64
#  3   previous_cancellations    119390 non-null  int64
#  4   wrong_room                119390 non-null  int64
#  5   customer_type_new         119390 non-null  int64
#  6   no_deposit                119390 non-null  int64
#  7   Family                    119390 non-null  int64
#  8   distribution_channel_new  119390 non-null  int64
#  9   adr_bin                   119390 non-null  int64
#  10  stays_in_weekend_nights   119390 non-null  int64
# dtypes: int64(11)
# memory usage: 10.0 MB

# %%
sample['lead_time_bin'] = sample['lead_time_bin'].astype('float64')
sample['is_repeated_guest'] = sample['is_repeated_guest'].astype('float64')
sample['previous_cancellations'] = sample['previous_cancellations'].astype('float64')
sample['wrong_room'] = sample['wrong_room'].astype('float64')
sample['customer_type_new'] = sample['customer_type_new'].astype('float64')
sample['no_deposit'] = sample['no_deposit'].astype('float64')
sample['Family'] = sample['Family'].astype('float64')
sample['distribution_channel_new'] = sample['distribution_channel_new'].astype('float64')
sample['adr_bin'] = sample['adr_bin'].astype('float64')
sample['stays_in_weekend_nights'] = sample['stays_in_weekend_nights'].astype('float64')
# Out:
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Dell_Owner\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   is_canceled               119390 non-null  int64
#  1   lead_time_bin             119390 non-null  float64
#  2   is_repeated_guest         119390 non-null  float64
#  3   previous_cancellations    119390 non-null  float64
#  4   wrong_room                119390 non-null  float64
#  5   customer_type_new         119390 non-null  float64
#  6   no_deposit                119390 non-null  float64
#  7   Family                    119390 non-null  float64
#  8   distribution_channel_new  119390 non-null  float64
#  9   adr_bin                   119390 non-null  float64
#  10  stays_in_weekend_nights   119390 non-null  float64
# dtypes: float64(10), int64(1)
# memory usage: 10.0 MB

# %%
X = sample.drop('is_canceled',axis=1)
y = sample['is_canceled']

# %%
cancel_corr = sample.corr()['is_canceled']
cancel_corr.abs().sort_values(ascending = True)[1:]
pd.DataFrame(cancel_corr).abs().sort_values('is_canceled',ascending = False)
# Out:
#                           is_canceled
# is_canceled                  1.000000
# no_deposit                   0.477911
# lead_time_bin                0.281380
# previous_cancellations       0.270943
# wrong_room                   0.247770
# distribution_channel_new     0.171684
# customer_type_new            0.135819
# is_repeated_guest            0.084793
# adr_bin                      0.059275
# stays_in_weekend_nights      0.008399
# Family                       0.003750

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# VIF dataframe 
X = pd.DataFrame(X)

vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 

# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
vif_data = vif_data.sort_values('VIF',ascending = False).reset_index().drop('index',axis=1)
vif_data
# Out:
#                     feature       VIF
# 0                no_deposit  8.230963
# 1                   adr_bin  7.803549
# 2             lead_time_bin  4.771935
# 3         customer_type_new  4.268134
# 4  distribution_channel_new  4.221377
# 5   stays_in_weekend_nights  2.407249
# 6                wrong_room  1.208274
# 7    previous_cancellations  1.206071
# 8                    Family  1.162634
# 9         is_repeated_guest  1.140821

# %%
sample.to_csv(r'C:\Users\Dell_Owner\Desktop\Project_650\model_data.csv', index = False)
df.to_csv(r'C:\Users\Dell_Owner\Desktop\Project_650\full_data.csv', index = False)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.linear_model import SGDClassifier,Lasso, LassoCV, lars_path
from sklearn.linear_model import LassoLarsIC as LIC
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.svm import SVC

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
model_log = LogisticRegression(solver = 'lbfgs' ,random_state=0)
model_log.fit(scaler.transform(X_train), y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
pred_log = model_log.predict(scaler.transform((X_test)))
metrics.mean_squared_error(y_true=y_test, y_pred=pred_log)
# Out:
# 0.23207585097829

# %%
model_log.coef_
# Out:
# array([[ 0.32685548, -0.40666312,  0.91445311, -0.66636848, -0.32631717,
#         -1.49472789,  0.05252023, -0.27904334,  0.13763143, -0.02125233]])

# %%
model_log.score(scaler.transform(X_train), y_train)
# Out:
# 0.7709566460431976

# %%
scores = cross_val_score(model_log, X_train, y_train, cv=10)
print('Cross-Validation Accuracy Scores', scores)
# Out:
# Cross-Validation Accuracy Scores [0.77286432 0.7692909  0.77138709 0.76837168 0.77239223 0.76814831
#  0.76479786 0.77362073 0.77350905 0.76423945]

# %%
scores = pd.Series(scores)
scores.min(), scores.mean(), scores.max()
# Out:
# (0.7642394460576278, 0.7698621604286291, 0.7736207281661827)

# %%
cm = confusion_matrix(y_true=y_test, y_pred=pred_log)
print('confusion matrix:\n', cm)
# Out:
# confusion matrix:
#  [[18166   687]
#  [ 6240  4755]]

# %%
tn, fp, fn, tp = cm.ravel()
print(f'tn: {tn}, fp: {fp}, fn: {fn}, tp: {tp}')
# Out:
# tn: 18166, fp: 687, fn: 6240, tp: 4755

# %%
plot = sns.heatmap(pd.DataFrame(cm), annot = True, cmap="YlGnBu")
plot.get_figure().savefig('cm.png', bbox_inches='tight')

# %%
print('classification report:\n', classification_report(y_test, pred_log))
# Out:
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84     18853
#            1       0.87      0.43      0.58     10995
#
#     accuracy                           0.77     29848
#    macro avg       0.81      0.70      0.71     29848
# weighted avg       0.79      0.77      0.74     29848
